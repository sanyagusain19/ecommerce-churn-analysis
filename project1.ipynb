# %% [markdown]
# ![Beige Minimalistic Project Summary Docs Banner.png](<attachment:Beige Minimalistic Project Summary Docs Banner.png>)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
! pip install openpyxl

# %% [markdown]
# <div class="alert alert-info">
# <centre>
#    <strong >  FIRST PROJECT:</strong>
# </centre>
# </div>

# %%
df=pd.read_excel("E Commerce Dataset.xlsx")
df.head(5)
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.tail(5)
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode Gender  HourSpendOnApp  \
# 5625             30.0          Credit Card   Male             3.0
# 5626             13.0          Credit Card   Male             3.0
# 5627             11.0           Debit Card   Male             3.0
# 5628              9.0          Credit Card   Male             4.0
# 5629             15.0          Credit Card   Male             3.0
#
#       NumberOfDeviceRegistered    PreferedOrderCat  SatisfactionScore  \
# 5625                         2  Laptop & Accessory                  1
# ...

# %%
# check null values:
df.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
df["Tenure"] = df["Tenure"].fillna(df["Tenure"].median())
df["Tenure"]
# Out:
# 0        4.0
# 1        9.0
# 2        9.0
# 3        0.0
# 4        0.0
#         ...
# 5625    10.0
# 5626    13.0
# 5627     1.0
# 5628    23.0
# 5629     8.0
# Name: Tenure, Length: 5630, dtype: float64

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                           0
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
cols = [
    'WarehouseToHome',
    'HourSpendOnApp',
    'OrderAmountHikeFromlastYear',
    'CouponUsed',
    'OrderCount',
    'DaySinceLastOrder'
]

for col in cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
#column id is not that useful therefore:
df = df.drop('CustomerID', axis=1)

# %%
df
# Out:
#       Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0         1     4.0         Mobile Phone         3              6.0
# 1         1     9.0                Phone         1              8.0
# 2         1     9.0                Phone         1             30.0
# 3         1     0.0                Phone         3             15.0
# 4         1     0.0                Phone         1             12.0
# ...     ...     ...                  ...       ...              ...
# 5625      0    10.0             Computer         1             30.0
# 5626      0    13.0         Mobile Phone         1             13.0
# 5627      0     1.0         Mobile Phone         1             11.0
# 5628      0    23.0             Computer         3              9.0
# 5629      0     8.0         Mobile Phone         1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# ...

# %%
y = df['Churn']  
y 
df = df.drop("Churn", axis = 1)   # Target/Result variable df.drop('Churn', axis=1)   # Features

# %%
df.head()
# Out:
#    Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0     4.0         Mobile Phone         3              6.0
# 1     9.0                Phone         1              8.0
# 2     9.0                Phone         1             30.0
# 3     0.0                Phone         3             15.0
# 4     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             3.0                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0  Laptop & Accessory                  2        Single                9
# ...

# %%
risk_score = (
    0.3 * (df["Tenure"] < 3).astype(int),
    0.2 * (df["CityTier"] == 1).astype(int),
    0.1 * (df["WarehouseToHome"] > 100 ).astype(int),
    0.1 * (df["HourSpendOnApp"] < 2 ).astype(int),
    0.4 * (df["SatisfactionScore"] < 3).astype(int)
)

# %%
df["WarehouseToHome"].sort_values()
# Out:
# 2201      5.0
# 1401      5.0
# 2151      5.0
# 451       5.0
# 1001      5.0
#         ...
# 4431     36.0
# 4512     36.0
# 4419     36.0
# 1309    126.0
# 4124    127.0
# Name: WarehouseToHome, Length: 5630, dtype: float64

# %%
df = df.copy()
df['Churn'] = y

# %%
y.value_counts( normalize= True) * 100
# Out:
# Churn
# 0    83.161634
# 1    16.838366
# Name: proportion, dtype: float64

# %%
df
# Out:
#       Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0        4.0         Mobile Phone         3              6.0
# 1        9.0                Phone         1              8.0
# 2        9.0                Phone         1             30.0
# 3        0.0                Phone         3             15.0
# 4        0.0                Phone         1             12.0
# ...      ...                  ...       ...              ...
# 5625    10.0             Computer         1             30.0
# 5626    13.0         Mobile Phone         1             13.0
# 5627     1.0         Mobile Phone         1             11.0
# 5628    23.0             Computer         3              9.0
# 5629     8.0         Mobile Phone         1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              Debit Card  Female             3.0                         3
# 1                     UPI    Male             3.0                         4
# ...

# %%
# Average tenure: churned vs retained
df.groupby('Churn')['Tenure'].mean()
# Out:
# Churn
# 0    11.404528
# 1     3.859705
# Name: Tenure, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='Tenure', data=df)
plt.title('Tenure vs Churn')
plt.xlabel('Churn (0 = Retained, 1 = Churned)')
plt.ylabel('Tenure (months)')
plt.show()

# %%
df['TenureGroup'] = pd.cut(df['Tenure'], bins=[-1,3,6,12,24,100], 
                             labels=['0-3m','4-6m','7-12m','1-2yr','2yr+'])

tenure_churn = df.groupby('TenureGroup')['Churn'].mean() * 100
print(tenure_churn)

tenure_churn.plot(kind='bar', color='coral')
plt.title('Churn Rate by Tenure Group')
plt.ylabel('Churn Rate (%)')
plt.show()
# Out:
# C:\Users\SANYA\AppData\Local\Temp\ipykernel_3292\3014943187.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tenure_churn = df.groupby('TenureGroup')['Churn'].mean() * 100
# TenureGroup
# 0-3m     41.858974
# 4-6m      7.457627
# 7-12m     9.848485
# 1-2yr     6.475801
# 2yr+      0.000000
# Name: Churn, dtype: float64

# %%
# Churn rate by City Tier
city_churn = df.groupby('CityTier')['Churn'].mean() * 100
print(city_churn)

city_churn.plot(kind='bar', color='steelblue')
plt.title('Churn Rate by City Tier')
plt.ylabel('Churn Rate (%)')
plt.xlabel('City Tier')
plt.show()
# Out:
# CityTier
# 1    14.511729
# 2    19.834711
# 3    21.370499
# Name: Churn, dtype: float64

# %%
# Churn rate by Complaint
complain_churn = df.groupby('Complain')['Churn'].mean() * 100
print(complain_churn)

complain_churn.plot(kind='bar', color='indianred')
plt.title('Churn Rate by Complaint Status')
plt.ylabel('Churn Rate (%)')
plt.xlabel('Complaint (0 = No, 1 = Yes)')
plt.show()
# Out:
# Complain
# 0    10.928962
# 1    31.670823
# Name: Churn, dtype: float64

# %%
# Churn by Satisfaction Score
sat_churn = df.groupby('SatisfactionScore')['Churn'].mean() * 100
print(sat_churn)

sat_churn.plot(kind='bar', color='slateblue')
plt.title('Churn Rate by Satisfaction Score')
plt.ylabel('Churn Rate (%)')
plt.show()
#high satisfaction != churn 0
# Out:
# SatisfactionScore
# 1    11.512027
# 2    12.627986
# 3    17.196702
# 4    17.132216
# 5    23.826715
# Name: Churn, dtype: float64

# %%
# Churn by Preferred Order Category
order_churn = df.groupby('PreferedOrderCat')['Churn'].mean().sort_values(ascending=False) * 100
print(order_churn)

order_churn.plot(kind='barh', color='mediumseagreen')
plt.title('Churn Rate by Order Category')
plt.xlabel('Churn Rate (%)')
plt.show()
# Out:
# PreferedOrderCat
# Mobile Phone          27.537372
# Mobile                27.194067
# Fashion               15.496368
# Laptop & Accessory    10.243902
# Others                 7.575758
# Grocery                4.878049
# Name: Churn, dtype: float64

# %%
# Average hours spent on app: churned vs retained
df.groupby('Churn')['HourSpendOnApp'].mean()
# Out:
# Churn
# 0    2.928663
# 1    2.964135
# Name: HourSpendOnApp, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='HourSpendOnApp', data=df,color="pink")
plt.title('App Usage Hours vs Churn')
plt.xlabel('Churn (0 = Retained, 1 = Churned)')
plt.ylabel('Hours Spent on App')
plt.show()

# %% [markdown]
# #app usaage time has almost nothing to do with this...

# %%
# Average days since last order: churned vs retained
df.groupby('Churn')['DaySinceLastOrder'].mean()
# Out:
# Churn
# 0    4.709739
# 1    3.222574
# Name: DaySinceLastOrder, dtype: float64

# %%
# Average coupons used: churned vs retained
df.groupby('Churn')['CouponUsed'].mean()
#doesnot matter!
# Out:
# Churn
# 0    1.718069
# 1    1.710970
# Name: CouponUsed, dtype: float64

# %% [markdown]
# Feature scaling:

# %%
# Drop ID column if present, separate target
X = df.drop(columns=['Churn'])
if 'CustomerID' in X.columns:
    X = X.drop(columns=['CustomerID'])

y = df['Churn']

print(X.shape, y.shape)
print(X.dtypes)
# Out:
# (5630, 19) (5630,)
# Tenure                          float64
# PreferredLoginDevice             object
# CityTier                          int64
# WarehouseToHome                 float64
# PreferredPaymentMode             object
# Gender                           object
# HourSpendOnApp                  float64
# NumberOfDeviceRegistered          int64
# PreferedOrderCat                 object
# SatisfactionScore                 int64
# MaritalStatus                    object
# NumberOfAddress                   int64
# Complain                          int64
# OrderAmountHikeFromlastYear     float64
# CouponUsed                      float64
# OrderCount                      float64
# DaySinceLastOrder               float64
# CashbackAmount                  float64
# TenureGroup                    category
# dtype: object

# %%
X.dtypes[X.dtypes == 'object']
# Out:
# PreferredLoginDevice    object
# PreferredPaymentMode    object
# Gender                  object
# PreferedOrderCat        object
# MaritalStatus           object
# dtype: object

# %%
categorical_cols = ['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus']

X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

print(X_encoded.shape)
print(X_encoded.columns.tolist())
# Out:
# (5630, 30)
# ['Tenure', 'CityTier', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount', 'TenureGroup', 'PreferredLoginDevice_Mobile Phone', 'PreferredLoginDevice_Phone', 'PreferredPaymentMode_COD', 'PreferredPaymentMode_Cash on Delivery', 'PreferredPaymentMode_Credit Card', 'PreferredPaymentMode_Debit Card', 'PreferredPaymentMode_E wallet', 'PreferredPaymentMode_UPI', 'Gender_Male', 'PreferedOrderCat_Grocery', 'PreferedOrderCat_Laptop & Accessory', 'PreferedOrderCat_Mobile', 'PreferedOrderCat_Mobile Phone', 'PreferedOrderCat_Others', 'MaritalStatus_Married', 'MaritalStatus_Single']

# %%
df['PreferredPaymentMode']
# Out:
# 0        Debit Card
# 1               UPI
# 2        Debit Card
# 3        Debit Card
# 4                CC
#            ...
# 5625    Credit Card
# 5626    Credit Card
# 5627     Debit Card
# 5628    Credit Card
# 5629    Credit Card
# Name: PreferredPaymentMode, Length: 5630, dtype: object

# %%
X_encoded.head()
# Out:
#    Tenure  CityTier  WarehouseToHome  HourSpendOnApp  \
# 0     4.0         3              6.0             3.0
# 1     9.0         1              8.0             3.0
# 2     9.0         1             30.0             2.0
# 3     0.0         3             15.0             2.0
# 4     0.0         1             12.0             3.0
#
#    NumberOfDeviceRegistered  SatisfactionScore  NumberOfAddress  Complain  \
# 0                         3                  2                9         1
# 1                         4                  3                7         1
# 2                         4                  3                6         1
# 3                         4                  5                8         0
# 4                         3                  5                3         0
#
#    OrderAmountHikeFromlastYear  CouponUsed  ...  \
# 0                         11.0         1.0  ...
# 1                         15.0         0.0  ...
# 2                         14.0         0.0  ...
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)

print(X_train.shape, X_test.shape)
print(y_train.value_counts (normalize = True))
print(y_test.value_counts(normalize=True))
# Out:
# (4504, 30) (1126, 30)
# Churn
# 0    0.831705
# 1    0.168295
# Name: proportion, dtype: float64
# Churn
# 0    0.831261
# 1    0.168739
# Name: proportion, dtype: float64

# %%
X_encoded.dtypes[X_encoded.dtypes == 'object']
# Out:
# Series([], dtype: object)

# %%
print(X_train.dtypes[X_train.dtypes == 'object'])
# Out:
# Series([], dtype: object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Done:", X_train_scaled.shape, X_test_scaled.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\SANYA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\categorical.py:592, in Categorical.astype(self, dtype, copy)
#     591 try:
# --> 592     new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     593     fill_value = self.categories._na_value
#
# ValueError: could not convert string to float: '0-3m'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 9
#       5     X_encoded, y, test_size=0.2, random_state=42, stratify=y
#       6 )
#       7
#       8 scaler = StandardScaler()
# ----> 9 X_train_scaled = scaler.fit_transform(X_train)
#      10 X_test_scaled = scaler.transform(X_test)
#      11
#      12 print("Done:", X_train_scaled.shape, X_test_scaled.shape)
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix, classification_report

log_model = LogisticRegression(max_iter=1000, random_state=42)
log_model.fit(X_train_scaled, y_train)

y_pred = log_model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8632326820603907
# Recall: 0.3
# Precision: 0.7307692307692307
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       936
#            1       0.73      0.30      0.43       190
#
#     accuracy                           0.86      1126
#    macro avg       0.80      0.64      0.67      1126
# weighted avg       0.85      0.86      0.84      1126

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rf_model.fit(X_train, y_train)  # note: tree models don't need scaled data

y_pred_rf = rf_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Recall:", recall_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Accuracy: 0.9573712255772646
# Recall: 0.7473684210526316
# Precision: 1.0
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       936
#            1       1.00      0.75      0.86       190
#
#     accuracy                           0.96      1126
#    macro avg       0.98      0.87      0.92      1126
# weighted avg       0.96      0.96      0.95      1126

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(n_estimators=200, random_state=42, eval_metric='logloss')
xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("Recall:", recall_score(y_test, y_pred_xgb))
print("Precision:", precision_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.9751332149200711
# Recall: 0.9
# Precision: 0.95
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       936
#            1       0.95      0.90      0.92       190
#
#     accuracy                           0.98      1126
#    macro avg       0.96      0.95      0.95      1126
# weighted avg       0.97      0.98      0.97      1126

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='rbf', class_weight='balanced', random_state=42)
svm_model.fit(X_train_scaled, y_train)  # SVM needs scaled data, like Logistic Regression

y_pred_svm = svm_model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Recall:", recall_score(y_test, y_pred_svm))
print("Precision:", precision_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# Accuracy: 0.8570159857904085
# Recall: 0.8526315789473684
# Precision: 0.5491525423728814
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       936
#            1       0.55      0.85      0.67       190
#
#     accuracy                           0.86      1126
#    macro avg       0.76      0.86      0.79      1126
# weighted avg       0.90      0.86      0.87      1126

# %%
import pandas as pd

importances = pd.Series(xgb_model.feature_importances_, index=X_encoded.columns)
importances = importances.sort_values(ascending=False)

print(importances.head(10))

importances.head(10).plot(kind='barh', figsize=(8,5))
plt.title('Top 10 Feature Importances (XGBoost)')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Complain                               0.100020
# PreferedOrderCat_Laptop & Accessory    0.069689
# MaritalStatus_Single                   0.062843
# PreferredPaymentMode_E wallet          0.050137
# PreferredPaymentMode_COD               0.045068
# CityTier                               0.044986
# PreferredPaymentMode_UPI               0.041838
# PreferedOrderCat_Mobile                0.041406
# PreferedOrderCat_Others                0.039152
# PreferedOrderCat_Grocery               0.037041
# dtype: float32

# %% [markdown]
# ## Business Recommendations
#
# 1. **Fix the first 90 days** — New customers (0-3 months) churn at ~42%, the highest of any group. A structured onboarding program with milestone-based incentives could reduce early churn.
#
# 2. **Treat complaints as a churn emergency** — Complaint filers churn at 3x the rate of non-complainers (32% vs 11%). Fast-resolution queues + automatic retention offers post-complaint are warranted.
#
# 3. **Invest in Tier 2/3 city service** — Tier 3 churn (21%) is notably higher than Tier 1 (14.5%), suggesting operational gaps like delivery speed rather than customer preference.
#
# 4. **Re-engage mobile/electronics buyers** — This segment churns at ~27% vs ~5% for grocery, likely due to one-time, comparison-shopped purchases. Post-purchase engagement could help convert them to repeat buyers.
#
# 5. **Deploy the model in production** — XGBoost catches 90% of churners at 95% precision. Monthly scoring of the customer base would let the retention team act before customers leave, not after.

# %%
importances = pd.Series(xgb_model.feature_importances_, index=X_encoded.columns)
print(importances.sort_values(ascending=False).head(10))
# Out:
# Complain                               0.100020
# PreferedOrderCat_Laptop & Accessory    0.069689
# MaritalStatus_Single                   0.062843
# PreferredPaymentMode_E wallet          0.050137
# PreferredPaymentMode_COD               0.045068
# CityTier                               0.044986
# PreferredPaymentMode_UPI               0.041838
# PreferedOrderCat_Mobile                0.041406
# PreferedOrderCat_Others                0.039152
# PreferedOrderCat_Grocery               0.037041
# dtype: float32
